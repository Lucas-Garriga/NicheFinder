# %%
pd.set_option("display.max_columns", None)

# %%
from pathlib import Path
import pandas as pd
import sqlite3

raw_path = Path("../data/scraped/raw_data_2025-07-11-16-10-55.csv")
df_raw = pd.read_csv(raw_path)

df_raw.head()
# Out:
#                                                title   price  rating   votes  \
# 0  DJI Bundle Essentiel Osmo Action 5 Pro, Caméra...  366.00     4.5  1673.0
# 1  DJI Osmo Pocket 3 Créateur Bundle, camera vlog...  679.00     4.6  5257.0
# 2  DJI Bundle Standard Osmo Action 5 Pro, Caméra ...     NaN     4.5  1673.0
# 3  Insta360 X5 Pack Essentiels - caméra d'action ...  699.99     4.6   722.0
# 4  Garmin – Forerunner 55 - Montre GPS multi-acti...  139.99     4.6  6619.0
#
#    sales_last_month                                          image_url  \
# 0               400  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 1               500  https://m.media-amazon.com/images/I/51mX1K3tM0...
# 2               300  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 3               200  https://m.media-amazon.com/images/I/71NlchaTFy...
# 4                 1  https://m.media-amazon.com/images/I/61eTqEILa9...
#
#                                                  url  prime  \
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             24 non-null     object
#  1   price             18 non-null     float64
#  2   rating            23 non-null     float64
#  3   votes             23 non-null     float64
#  4   sales_last_month  24 non-null     int64
#  5   image_url         24 non-null     object
#  6   url               24 non-null     object
#  7   prime             24 non-null     bool
#  8   scraped_at        24 non-null     object
# dtypes: bool(1), float64(3), int64(1), object(4)
# memory usage: 1.7+ KB

# %%
clean_path = Path("../data/cleaned/df_clean_2025-07-11.csv")
df_clean = pd.read_csv(clean_path)
df_clean.head()
# Out:
#                                                title   price  rating   votes  \
# 0  DJI Bundle Essentiel Osmo Action 5 Pro, Caméra...  366.00     4.5  1673.0
# 1  DJI Osmo Pocket 3 Créateur Bundle, camera vlog...  679.00     4.6  5257.0
# 2  DJI Bundle Standard Osmo Action 5 Pro, Caméra ...    0.00     4.5  1673.0
# 3  Insta360 X5 Pack Essentiels - caméra d'action ...  699.99     4.6   722.0
# 4  Garmin – Forerunner 55 - Montre GPS multi-acti...  139.99     4.6  6619.0
#
#    sales_last_month                                          image_url  \
# 0               400  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 1               500  https://m.media-amazon.com/images/I/51mX1K3tM0...
# 2               300  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 3               200  https://m.media-amazon.com/images/I/71NlchaTFy...
# 4                 1  https://m.media-amazon.com/images/I/61eTqEILa9...
#
#                                                  url  prime  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             24 non-null     object
#  1   price             24 non-null     float64
#  2   rating            24 non-null     float64
#  3   votes             24 non-null     int64
#  4   sales_last_month  24 non-null     int64
#  5   image_url         24 non-null     object
#  6   url               24 non-null     object
#  7   prime             24 non-null     bool
#  8   scraped_at        24 non-null     object
#  9   categorie         24 non-null     object
#  10  classement        24 non-null     int64
#  11  published_date    24 non-null     object
#  12  full_title        24 non-null     object
# dtypes: bool(1), float64(2), int64(3), object(7)
# memory usage: 2.4+ KB

# %%
df_clean.columns
# Out:
# Index(['title', 'price', 'rating', 'votes', 'sales_last_month', 'image_url',
#        'url', 'prime', 'scraped_at', 'categorie', 'classement',
#        'published_date', 'full_title'],
#       dtype='object')

# %%
df_clean.head()
# Out:
#                                                title   price  rating  votes  \
# 0  DJI Bundle Essentiel Osmo Action 5 Pro, Caméra...  375.00     4.5   1660
# 1  DJI Osmo Pocket 3 Créateur Bundle, camera vlog...  679.00     4.6   5248
# 2  DJI Bundle Standard Osmo Action 5 Pro, Caméra ...    0.00     4.5   1660
# 3  Insta360 X5 Pack Essentiels - caméra d'action ...  699.99     4.6    715
# 4  Garmin – Forerunner 55 - Montre GPS multi-acti...  139.99     4.6   6615
#
#    sales_last_month                                          image_url  \
# 0               400  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 1               500  https://m.media-amazon.com/images/I/51mX1K3tM0...
# 2               300  https://m.media-amazon.com/images/I/71LN4iT1Pq...
# 3               200  https://m.media-amazon.com/images/I/71NlchaTFy...
# 4               900  https://m.media-amazon.com/images/I/61eTqEILa9...
#
#                                                  url  prime  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 44 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   title                                      24 non-null     object
#  1   price                                      24 non-null     float64
#  2   rating                                     24 non-null     float64
#  3   votes                                      24 non-null     int64
#  4   sales_last_month                           24 non-null     int64
#  5   image_url                                  24 non-null     object
#  6   url                                        24 non-null     object
#  7   prime                                      24 non-null     bool
#  8   scraped_at                                 24 non-null     object
#  9   categorie                                  24 non-null     object
# ...

# %%
df_clean[df_clean['High-Tech'] == 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Downloads/CV/Data/NicheFinder/NicheFinder/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High-Tech'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ...

# %%
df3 = pd.read_csv("df_extract.csv")
df3.head()
# Out:
#                                                titre  \
# 0  DJI Osmo Pocket 3 Créateur Bundle, camera vlog...
# 1  DJI Bundle Essentiel Osmo Action 5 Pro, Caméra...
# 2  Insta360 X5 - caméra d'action 360° 8K étanche,...
# 3  DJI Bundle Standard Osmo Action 5 Pro, Caméra ...
# 4  Garmin – Forerunner 55 - Montre GPS multi-acti...
#
#                                                  url  \
# 0  https://www.amazon.fr/DJI-Cr%C3%A9ateur-Vloggi...
# 1  https://www.amazon.fr/DJI-Essentiel-%C3%89tanc...
# 2  https://www.amazon.fr/Insta360-Invisible-rempl...
# 3  https://www.amazon.fr/DJI-Standard-%C3%89tanch...
# 4  https://www.amazon.fr/Garmin-Forerunner-multi-...
#
#                                            categorie  \
# 0  ["['High-Tech', 'Photo et caméscopes', 'Caméra...
# 1  ["['High-Tech', 'Photo et caméscopes', 'Appare...
# 2  ["['High-Tech', 'Photo et caméscopes', 'Caméra...
# 3  ["['High-Tech', 'Photo et caméscopes', 'Caméra...
# ...

# %%
df3[pd.isna(df3["High-Tech"])]
# Out:
#                                                   titre  \
# 4     Garmin – Forerunner 55 - Montre GPS multi-acti...
# 6     Garmin Forerunner 255 - Montre GPS Multisports...
# 8     Garmin Forerunner 255, Music - Montre GPS Mult...
# 11    OMRON RS1 Tensiomètre automatique au poignet p...
# 12    Garmin – Forerunner 55 - Montre GPS multi-acti...
# ...                                                 ...
# 4554  WOLFANG Caméra Sport GA420 4K60FPS & Ensemble ...
# 4555  Lot de 30/50/100 accessoires de réalité virtue...
# 4557  Écouteurs intra-auriculaires Bluetooth, sans f...
# 4558  XUXN G01 Casque tour de cou à suspendre sans f...
# 4559  Lot de 30/50/100 coussinets jetables VR pour m...
#
#                                                     url  \
# 4     https://www.amazon.fr/Garmin-Forerunner-multi-...
# 6     https://www.amazon.fr/Garmin-GPS-Forerunner-25...
# 8     https://www.amazon.fr/Garmin-Forerunner-255-Mu...
# 11    https://www.amazon.fr/OMRON-Tensiom%C3%A8tre-P...
# ...
